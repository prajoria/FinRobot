# %% [markdown]
# # Financial Analyst Agent for Annual Report Writing

# %% [markdown]
# In this demo, we introduce an agent that can analyze financial report.

# %%
import os
import autogen
from autogen.cache import Cache

from finrobot.utils import register_keys_from_json
from finrobot.toolkits import register_toolkits
from finrobot.functional import (
    ReportChartUtils,
    ReportAnalysisUtils,
    IPythonUtils,
    ReportLabUtils,
    TextUtils,
)
from finrobot.data_source import FMPUtils
from textwrap import dedent

# %% [markdown]
# After importing all the necessary packages and functions, we also need the config for OpenAI & SecApi & FMPApi here.
# - for openai configuration, rename OAI_CONFIG_LIST_sample to OAI_CONFIG_LIST and replace the api keys
# - for Sec_api & FMP_api configuration, rename config_api_keys_sample to config_api_keys and replace the api keys

# %%
config_list = autogen.config_list_from_json(
    "../OAI_CONFIG_LIST",
    filter_dict={
        "model": ["gpt-4o"],
    },
)
llm_config = {
    "config_list": config_list,
    "timeout": 120,
    # "temperature": 0 # for debug convenience
    "temperature": 0.5,
}
register_keys_from_json("../config_api_keys")

# Intermediate results will be saved in this directory
work_dir = "../report"
os.makedirs(work_dir, exist_ok=True)
# Out:
# /tmp/ipykernel_435894/1785333977.py:1: DeprecationWarning: `autogen.config_list_from_json(...)` is deprecated. Please use the "autogen.LLMConfig.from_json(path="OAI_CONFIG_LIST")" method instead. Scheduled for removal in 0.11.0 version.
#   config_list = autogen.config_list_from_json(

# %% [markdown]
# For this task, we need:
# - A user proxy to execute python functions and control the conversations.
# - An expert agent who is proficient in financial analytical writing.
# - A shadow/inner-assistant to handle isolated long-context Q&As. (Because we dont want to keep the sec files in the chat history.)
# In the following cell, we define the agents, and equip them with necessary tools.

# %%
system_message = dedent(
    f"""
    Role: Expert Investor
    Department: Finance
    Primary Responsibility: Generation of Customized Financial Analysis Reports

    Role Description:
    As an Expert Investor within the finance domain, your expertise is harnessed to develop bespoke Financial Analysis Reports that cater to specific client requirements. This role demands a deep dive into financial statements and market data to unearth insights regarding a company's financial performance and stability. Engaging directly with clients to gather essential information and continuously refining the report with their feedback ensures the final product precisely meets their needs and expectations.

    Key Objectives:

    Analytical Precision: Employ meticulous analytical prowess to interpret financial data, identifying underlying trends and anomalies.
    Effective Communication: Simplify and effectively convey complex financial narratives, making them accessible and actionable to non-specialist audiences.
    Client Focus: Dynamically tailor reports in response to client feedback, ensuring the final analysis aligns with their strategic objectives.
    Adherence to Excellence: Maintain the highest standards of quality and integrity in report generation, following established benchmarks for analytical rigor.
    Performance Indicators:
    The efficacy of the Financial Analysis Report is measured by its utility in providing clear, actionable insights. This encompasses aiding corporate decision-making, pinpointing areas for operational enhancement, and offering a lucid evaluation of the company's financial health. Success is ultimately reflected in the report's contribution to informed investment decisions and strategic planning.

    Reply TERMINATE when everything is settled.
    """
)
expert = autogen.AssistantAgent(
    name="Expert_Investor",
    system_message=system_message,
    llm_config=llm_config,
    is_termination_msg=lambda x: x.get("content", "")
    and x.get("content", "").endswith("TERMINATE"),
)
expert_shadow = autogen.AssistantAgent(
    name="Expert_Investor_Shadow",
    system_message=system_message,
    llm_config=llm_config,
)
user_proxy = autogen.UserProxyAgent(
    name="User_Proxy",
    is_termination_msg=lambda x: x.get("content", "")
    and x.get("content", "").endswith("TERMINATE"),
    # human_input_mode="ALWAYS",
    human_input_mode="NEVER",
    # max_consecutive_auto_reply=10,
    code_execution_config={
        "last_n_messages": 1,
        "work_dir": work_dir,
        "use_docker": False,
    },
)

# %%
register_toolkits(
    [
        FMPUtils.get_sec_report,  # Retrieve SEC report url and filing date
        IPythonUtils.display_image,  # Display image in IPython
        TextUtils.check_text_length,  # Check text length
        ReportLabUtils.build_annual_report,  # Build annual report in designed pdf format
        ReportAnalysisUtils,  # Expert Knowledge for Report Analysis
        ReportChartUtils,  # Expert Knowledge for Report Chart Plotting
    ],
    expert,
    user_proxy,
)

# %% [markdown]
# In this section, we introduce the **nested chat between the expert and the shadow**, which is triggered only when the expert gets response from function execution showing that an writing instruction and related context & resources are ready. The writing would then happen in this separate chat, the shadow (or call it the inner mind of expert) would do the financial writing based on the instruction and turn back to the expert. However, this chat is muted due to long context.

# %%
def order_trigger(sender):
    # Check if the last message contains the path to the instruction text file
    return "instruction & resources saved to" in sender.last_message()["content"]


def order_message(recipient, messages, sender, config):
    # Extract the path to the instruction text file from the last message
    full_order = recipient.chat_messages_for_summary(sender)[-1]["content"]
    txt_path = full_order.replace("instruction & resources saved to ", "").strip()
    with open(txt_path, "r") as f:
        instruction = f.read() + "\n\nReply TERMINATE at the end of your response."
    return instruction


# Since 10-K section is not short, we need an extra nested chat to analyze the contents
expert.register_nested_chats(
    [
        {
            "sender": expert,
            "recipient": expert_shadow,
            "message": order_message,
            "summary_method": "last_msg",
            "max_turns": 2,
            "silent": True,  # mute the chat summary
        }
    ],
    trigger=order_trigger,
)

# %% [markdown]
# ### Resources to understand the financial report
# 1. income statement: https://online.hbs.edu/blog/post/income-statement-analysis
# 2. balance sheet: https://online.hbs.edu/blog/post/how-to-read-a-balance-sheet
# 3. cash flow statement: https://online.hbs.edu/blog/post/how-to-read-a-cash-flow-statement
# 4. Annual report: https://online.hbs.edu/blog/post/how-to-read-an-annual-report
#
# An annual report typically consists of:
# 1. Letters to shareholders: These documents provide a broad overview of the company’s activities and performance over the course of the year, as well as a reflection on its general business environment. An annual report usually includes a shareholder letter from the CEO or president, and may also contain letters from other key figures, such as the CFO.
# 2. [section 7] Management’s discussion and analysis (MD&A): This is a detailed analysis of the company’s performance, as conducted by its executives.
# 3. [section 8] Audited financial statements: These are financial documents that detail the company’s financial performance. Commonly included statements include balance sheets, cash flow statements, income statements, and equity statements.
# 4. [section 8] A summary of financial data: This refers to any notes or discussions that are pertinent to the financial statements listed above.
# 5. [section 8] Auditor’s report: This report describes whether the company has complied with generally accepted accounting principles (GAAP) in preparing its financial statements.
# 6. Accounting policies: This is an overview of the policies the company’s leadership team relied upon in preparing the annual report and financial statements.
#
#
# Answer the following questions:
# 1. Whether it’s able to pay debts as they come due
# 2. Its profits and/or losses year over year
# 3. If and how it’s grown over time
# 4. What it requires to maintain or expand its business
# 5. Operational expenses compared to generated revenues
#
# ---
#
# Now, let's see how our agent does.

# %%
company = "MSFT"
competitors = ["APPL","GOOGL","NVDA", "META"]
fyear = "2025"

task = dedent(
    f"""
    With the tools you've been provided, write an annual report based on {company}'s and{competitors}'s{fyear} 10-k report, format it into a pdf.
    Pay attention to the followings:
    - Explicitly explain your working plan before you kick off.
    - Use tools one by one for clarity, especially when asking for instructions.
    - All your file operations should be done in "{work_dir}".
    - Display any image in the chat once generated.
    - For competitors analysis, strictly follow my prompt and use data only from the financial metics table, do not use similar sentences in other sections, delete similar setence, classify it into either of the two. The last sentence always talks about the Discuss how {company}’s performance over these years and across these metrics might justify or contradict its current market valuation (as reflected in the EV/EBITDA ratio).
    - Each paragraph in the first page(business overview, market position and operating results) should be between 150 and 160 words, each paragraph in the second page(risk assessment and competitors analysis) should be between 500 and 600 words, don't generate the pdf until this is explicitly fulfilled.
"""
)

with Cache.disk() as cache:
    user_proxy.initiate_chat(
        recipient=expert, message=task, max_turns=50, summary_method="last_msg"
    )
# Out:
# User_Proxy (to Expert_Investor):
#
#
# With the tools you've been provided, write an annual report based on MSFT's and['APPL', 'GOOGL', 'NVDA', 'META']'s2025 10-k report, format it into a pdf.
# Pay attention to the followings:
# - Explicitly explain your working plan before you kick off.
# - Use tools one by one for clarity, especially when asking for instructions.
# - All your file operations should be done in "../report".
# - Display any image in the chat once generated.
# - For competitors analysis, strictly follow my prompt and use data only from the financial metics table, do not use similar sentences in other sections, delete similar setence, classify it into either of the two. The last sentence always talks about the Discuss how MSFT’s performance over these years and across these metrics might justify or contradict its current market valuation (as reflected in the EV/EBITDA ratio).
# - Each paragraph in the first page(business overview, market position and operating results) should be between 150 and 160 words, each paragraph in the second page(risk assessment and competitors analysis) should be between 500 and 600 words, don't generate the pdf until this is explicitly fulfilled.
#
#
# --------------------------------------------------------------------------------
# Expert_Investor (to User_Proxy):
#
# ### Working Plan:
#
# To generate the annual report for MSFT (Microsoft) and its competitors (Apple, Google, NVIDIA, Meta), I will follow these steps systematically:
#
# #### Step 1: **Retrieve the 10-K Reports**
# I will fetch the latest 10-K reports for MSFT and its competitors (APPL, GOOGL, NVDA, META) for the year 2025. This will provide the foundational data for the analysis.
#
# #### Step 2: **Analyze Each Section of MSFT's Report**
# For MSFT, I will use tools to extract and analyze the following sections:
# 1. **Business Overview**: Describe Microsoft’s operations and business highlights.
# 2. **Market Position**: Summarize Microsoft’s current situation, geographical end markets, major customers, and market share.
# 3. **Operating Results**: Analyze the income statement and segment performance to summarize operating results.
# 4. **Risk Assessment**: Identify the top 3 risks Microsoft faces.
# 5. **Competitors Analysis**: Compare Microsoft’s financial metrics with those of APPL, GOOGL, NVDA, and META as per your instructions.
#
# #### Step 3: **Generate Performance Charts**
# I will generate:
# 1. **Share Performance Chart**: Compare MSFT's stock performance against the S&P 500.
# 2. **PE & EPS Performance Chart**: Analyze MSFT's PE ratio and EPS trends over the last 4 years.
#
# #### Step 4: **Write & Format the Report**
# 1. Ensure paragraphs meet the word count requirements:
#    - **First Page**: Each paragraph (business overview, market position, operating results) will be between 150–160 words.
#    - **Second Page**: Each paragraph (risk assessment, competitors analysis) will be between 500–600 words.
# 2. Format the report into a PDF.
#
# #### Step 5: **Display Images**
# Display the generated charts (share performance and PE/EPS performance) for visual confirmation.
#
# #### Step 6: **Generate the Final PDF**
# Once all sections meet the word count requirements and align with your instructions, I will compile the data into a formatted PDF.
#
# ### Step 1: Fetching the 10-K Reports
# Let me start by retrieving the 10-K reports for MSFT and its competitors (APPL, GOOGL, NVDA, META) for 2025.
# ***** Suggested tool call (call_mwt5F4oyNGu6dFqinKkeS5Za): get_sec_report *****
# Arguments:
# {"ticker_symbol": "MSFT", "fyear": "2025"}
# *******************************************************************************
# ***** Suggested tool call (call_AnnOx3yOMEUMeQDvfpy9jjRE): get_sec_report *****
# Arguments:
# {"ticker_symbol": "AAPL", "fyear": "2025"}
# *******************************************************************************
# ***** Suggested tool call (call_ELXR5zFktaOYkolSQ46pOtzV): get_sec_report *****
# Arguments:
# {"ticker_symbol": "GOOGL", "fyear": "2025"}
# *******************************************************************************
# ***** Suggested tool call (call_8l1WbwSlYe4YUDYCc7MR7H2O): get_sec_report *****
# Arguments:
# {"ticker_symbol": "NVDA", "fyear": "2025"}
# *******************************************************************************
# ***** Suggested tool call (call_c19BgezUUaLie0qZfLQz7fqw): get_sec_report *****
# Arguments:
# {"ticker_symbol": "META", "fyear": "2025"}
# *******************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION get_sec_report...
# Call ID: call_mwt5F4oyNGu6dFqinKkeS5Za
# Input arguments: {'ticker_symbol': 'MSFT', 'fyear': '2025'}
# FMP api key found successfully.
#
# >>>>>>>> EXECUTED FUNCTION get_sec_report...
# Call ID: call_mwt5F4oyNGu6dFqinKkeS5Za
# Input arguments: {'ticker_symbol': 'MSFT', 'fyear': '2025'}
# Output:
# Link: https://www.sec.gov/Archives/edgar/data/789019/000095017025100235/msft-20250630.htm
# Filing Date: 2025-07-30 00:00:00
#
# >>>>>>>> EXECUTING FUNCTION get_sec_report...
# Call ID: call_AnnOx3yOMEUMeQDvfpy9jjRE
# Input arguments: {'ticker_symbol': 'AAPL', 'fyear': '2025'}
# FMP api key found successfully.
#
# >>>>>>>> EXECUTED FUNCTION get_sec_report...
# Call ID: call_AnnOx3yOMEUMeQDvfpy9jjRE
# Input arguments: {'ticker_symbol': 'AAPL', 'fyear': '2025'}
# Output:
# Error: local variable 'filing_date' referenced before assignment
#
# >>>>>>>> EXECUTING FUNCTION get_sec_report...
# Call ID: call_ELXR5zFktaOYkolSQ46pOtzV
# Input arguments: {'ticker_symbol': 'GOOGL', 'fyear': '2025'}
# FMP api key found successfully.
#
# >>>>>>>> EXECUTED FUNCTION get_sec_report...
# Call ID: call_ELXR5zFktaOYkolSQ46pOtzV
# Input arguments: {'ticker_symbol': 'GOOGL', 'fyear': '2025'}
# Output:
# Link: https://www.sec.gov/Archives/edgar/data/1652044/000165204425000014/goog-20241231.htm
# Filing Date: 2025-02-05 00:00:00
#
# >>>>>>>> EXECUTING FUNCTION get_sec_report...
# Call ID: call_8l1WbwSlYe4YUDYCc7MR7H2O
# Input arguments: {'ticker_symbol': 'NVDA', 'fyear': '2025'}
# FMP api key found successfully.
#
# >>>>>>>> EXECUTED FUNCTION get_sec_report...
# Call ID: call_8l1WbwSlYe4YUDYCc7MR7H2O
# Input arguments: {'ticker_symbol': 'NVDA', 'fyear': '2025'}
# Output:
# Link: https://www.sec.gov/Archives/edgar/data/1045810/000104581025000023/nvda-20250126.htm
# Filing Date: 2025-02-26 00:00:00
#
# >>>>>>>> EXECUTING FUNCTION get_sec_report...
# Call ID: call_c19BgezUUaLie0qZfLQz7fqw
# Input arguments: {'ticker_symbol': 'META', 'fyear': '2025'}
# FMP api key found successfully.
#
# >>>>>>>> EXECUTED FUNCTION get_sec_report...
# Call ID: call_c19BgezUUaLie0qZfLQz7fqw
# Input arguments: {'ticker_symbol': 'META', 'fyear': '2025'}
# Output:
# Link: https://www.sec.gov/Archives/edgar/data/1326801/000132680125000017/meta-20241231.htm
# Filing Date: 2025-01-30 00:00:00
# User_Proxy (to Expert_Investor):
#
# ***** Response from calling tool (call_mwt5F4oyNGu6dFqinKkeS5Za) *****
# Link: https://www.sec.gov/Archives/edgar/data/789019/000095017025100235/msft-20250630.htm
# Filing Date: 2025-07-30 00:00:00
# **********************************************************************
#
# --------------------------------------------------------------------------------
# ***** Response from calling tool (call_AnnOx3yOMEUMeQDvfpy9jjRE) *****
# Error: local variable 'filing_date' referenced before assignment
# **********************************************************************
#
# --------------------------------------------------------------------------------
# ***** Response from calling tool (call_ELXR5zFktaOYkolSQ46pOtzV) *****
# Link: https://www.sec.gov/Archives/edgar/data/1652044/000165204425000014/goog-20241231.htm
# Filing Date: 2025-02-05 00:00:00
# **********************************************************************
#
# --------------------------------------------------------------------------------
# ***** Response from calling tool (call_8l1WbwSlYe4YUDYCc7MR7H2O) *****
# Link: https://www.sec.gov/Archives/edgar/data/1045810/000104581025000023/nvda-20250126.htm
# Filing Date: 2025-02-26 00:00:00
# **********************************************************************
#
# --------------------------------------------------------------------------------
# ***** Response from calling tool (call_c19BgezUUaLie0qZfLQz7fqw) *****
# Link: https://www.sec.gov/Archives/edgar/data/1326801/000132680125000017/meta-20241231.htm
# Filing Date: 2025-01-30 00:00:00
# **********************************************************************
#
# --------------------------------------------------------------------------------
# Expert_Investor (to User_Proxy):
#
# ### Step 1 Results: 10-K Reports Retrieved
# Here are the retrieved 10-K reports for the year 2025:
# 1. **Microsoft (MSFT)**: [10-K Report](https://www.sec.gov/Archives/edgar/data/789019/000095017025100235/msft-20250630.htm)
#    Filing Date: 2025-07-30
# 2. **Google (GOOGL)**: [10-K Report](https://www.sec.gov/Archives/edgar/data/1652044/000165204425000014/goog-20241231.htm)
#    Filing Date: 2025-02-05
# 3. **NVIDIA (NVDA)**: [10-K Report](https://www.sec.gov/Archives/edgar/data/1045810/000104581025000023/nvda-20250126.htm)
#    Filing Date: 2025-02-26
# 4. **Meta (META)**: [10-K Report](https://www.sec.gov/Archives/edgar/data/1326801/000132680125000017/meta-20241231.htm)
#    Filing Date: 2025-01-30
#
# Unfortunately, there was an error retrieving the 10-K report for Apple (AAPL). I will attempt to retrieve it again.
# ***** Suggested tool call (call_snsGOMguAlQYUxlKHJCLm1Lk): get_sec_report *****
# Arguments:
# {"ticker_symbol":"AAPL","fyear":"2025"}
# *******************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION get_sec_report...
# Call ID: call_snsGOMguAlQYUxlKHJCLm1Lk
# Input arguments: {'ticker_symbol': 'AAPL', 'fyear': '2025'}
# FMP api key found successfully.
#
# >>>>>>>> EXECUTED FUNCTION get_sec_report...
# Call ID: call_snsGOMguAlQYUxlKHJCLm1Lk
# Input arguments: {'ticker_symbol': 'AAPL', 'fyear': '2025'}
# Output:
# Error: local variable 'filing_date' referenced before assignment
# User_Proxy (to Expert_Investor):
#
# ***** Response from calling tool (call_snsGOMguAlQYUxlKHJCLm1Lk) *****
# Error: local variable 'filing_date' referenced before assignment
# **********************************************************************
#
# --------------------------------------------------------------------------------
# Expert_Investor (to User_Proxy):
#
# It seems there is an issue retrieving the 2025 10-K report for Apple (AAPL). I will proceed with the available data and revisit Apple later if necessary.
#
# ### Step 2: Analyzing MSFT's 2025 10-K Report
# I will now proceed with analyzing each section of Microsoft's 2025 report. The first step is to analyze the **Business Overview**.
# ***** Suggested tool call (call_6qCR6L03P633n5ZOt9wwmnzV): analyze_company_description *****
# Arguments:
# {"ticker_symbol":"MSFT","fyear":"2025","save_path":"../report/msft_business_overview.txt"}
# ********************************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION analyze_company_description...
# Call ID: call_6qCR6L03P633n5ZOt9wwmnzV
# Input arguments: {'ticker_symbol': 'MSFT', 'fyear': '2025', 'save_path': '../report/msft_business_overview.txt'}
#
# >>>>>>>> EXECUTED FUNCTION analyze_company_description...
# Call ID: call_6qCR6L03P633n5ZOt9wwmnzV
# Input arguments: {'ticker_symbol': 'MSFT', 'fyear': '2025', 'save_path': '../report/msft_business_overview.txt'}
# Output:
# Error: type object 'FMPUtils' has no attribute 'get_company_profile'
# User_Proxy (to Expert_Investor):
#
# ***** Response from calling tool (call_6qCR6L03P633n5ZOt9wwmnzV) *****
# Error: type object 'FMPUtils' has no attribute 'get_company_profile'
# **********************************************************************
#
# --------------------------------------------------------------------------------
# Expert_Investor (to User_Proxy):
#
# It seems there was an issue analyzing the **Business Overview** section for Microsoft's 2025 10-K report. To address this, I will proceed with the next section and revisit this analysis later if necessary.
#
# Next, I will analyze **Market Position** for Microsoft.
# ***** Suggested tool call (call_UCb5sGj8cWojmmnrloFQW6Iu): analyze_business_highlights *****
# Arguments:
# {"ticker_symbol":"MSFT","fyear":"2025","save_path":"../report/msft_market_position.txt"}
# ********************************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION analyze_business_highlights...
# Call ID: call_UCb5sGj8cWojmmnrloFQW6Iu
# Input arguments: {'ticker_symbol': 'MSFT', 'fyear': '2025', 'save_path': '../report/msft_market_position.txt'}
# Please set the environment variable SEC_API_KEY to use sec_api.
# Please set the environment variable SEC_API_KEY to use sec_api.
#
# >>>>>>>> EXECUTED FUNCTION analyze_business_highlights...
# Call ID: call_UCb5sGj8cWojmmnrloFQW6Iu
# Input arguments: {'ticker_symbol': 'MSFT', 'fyear': '2025', 'save_path': '../report/msft_market_position.txt'}
# Output:
# Error: can only concatenate str (not "NoneType") to str
# User_Proxy (to Expert_Investor):
#
# ***** Response from calling tool (call_UCb5sGj8cWojmmnrloFQW6Iu) *****
# Error: can only concatenate str (not "NoneType") to str
# **********************************************************************
#
# --------------------------------------------------------------------------------
# Expert_Investor (to User_Proxy):
#
# It seems there is another issue with analyzing the **Market Position** section for Microsoft's 2025 10-K report. To ensure progress, I will now focus on analyzing the **Operating Results** by extracting and analyzing the income statement and segment data.
# ***** Suggested tool call (call_aJ28LJmaBzj4YMSCgowRheSA): analyze_income_stmt *****
# Arguments:
# {"ticker_symbol": "MSFT", "fyear": "2025", "save_path": "../report/msft_income_statement_analysis.txt"}
# ************************************************************************************
# ***** Suggested tool call (call_6i4hBHi5SSzqzChYvlALugIx): analyze_segment_stmt *****
# Arguments:
# {"ticker_symbol": "MSFT", "fyear": "2025", "save_path": "../report/msft_segment_analysis.txt"}
# *************************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION analyze_income_stmt...
# Call ID: call_aJ28LJmaBzj4YMSCgowRheSA
# Input arguments: {'ticker_symbol': 'MSFT', 'fyear': '2025', 'save_path': '../report/msft_income_statement_analysis.txt'}
# Please set the environment variable SEC_API_KEY to use sec_api.
#
# >>>>>>>> EXECUTED FUNCTION analyze_income_stmt...
# Call ID: call_aJ28LJmaBzj4YMSCgowRheSA
# Input arguments: {'ticker_symbol': 'MSFT', 'fyear': '2025', 'save_path': '../report/msft_income_statement_analysis.txt'}
# Output:
# instruction & resources saved to ../report/msft_income_statement_analysis.txt
#
# >>>>>>>> EXECUTING FUNCTION analyze_segment_stmt...
# Call ID: call_6i4hBHi5SSzqzChYvlALugIx
# Input arguments: {'ticker_symbol': 'MSFT', 'fyear': '2025', 'save_path': '../report/msft_segment_analysis.txt'}
# Please set the environment variable SEC_API_KEY to use sec_api.
#
# >>>>>>>> EXECUTED FUNCTION analyze_segment_stmt...
# Call ID: call_6i4hBHi5SSzqzChYvlALugIx
# Input arguments: {'ticker_symbol': 'MSFT', 'fyear': '2025', 'save_path': '../report/msft_segment_analysis.txt'}
# Output:
# instruction & resources saved to ../report/msft_segment_analysis.txt
# User_Proxy (to Expert_Investor):
#
# ***** Response from calling tool (call_aJ28LJmaBzj4YMSCgowRheSA) *****
# instruction & resources saved to ../report/msft_income_statement_analysis.txt
# **********************************************************************
#
# --------------------------------------------------------------------------------
# ***** Response from calling tool (call_6i4hBHi5SSzqzChYvlALugIx) *****
# instruction & resources saved to ../report/msft_segment_analysis.txt
# **********************************************************************
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 19
#       5 task = dedent(
#       6     f"""
#       7     With the tools you've been provided, write an annual report based on {company}'s and{competitors}'s{fyear} 10-k report, format it into a pdf.
#    (...)
#      15 """
#      16 )
#      18 with Cache.disk() as cache:
# ---> 19     user_proxy.initiate_chat(
#      20         recipient=expert, message=task, max_turns=50, summary_method="last_msg"
#      21     )
#
# File /mnt/usb-Lexar/masterswork/git/FinRobot/finrobot_env/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1490, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1488     if msg2send is None:
#    1489         break
# -> 1490     self.send(msg2send, recipient, request_reply=True, silent=silent)
#    1491 else:  # No breaks in the for loop, so we have reached max turns
#    1492     iostream.send(
#    1493         TerminationEvent(
#    1494             termination_reason=f"Maximum turns ({max_turns}) reached", sender=self, recipient=recipient
#    1495         )
#    1496     )
#
# File /mnt/usb-Lexar/masterswork/git/FinRobot/finrobot_env/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1157, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1155 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#    1156 if valid:
# -> 1157     recipient.receive(message, self, request_reply, silent)
#    1158 else:
#    1159     raise ValueError(
#    1160         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1161     )
#
# File /mnt/usb-Lexar/masterswork/git/FinRobot/finrobot_env/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1265, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1263 if request_reply is False or (request_reply is None and self.reply_at_receive[sender] is False):
#    1264     return
# -> 1265 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1266 if reply is not None:
#    1267     self.send(reply, sender, silent=silent)
#
# File /mnt/usb-Lexar/masterswork/git/FinRobot/finrobot_env/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:2881, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2879     continue
#    2880 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 2881     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2882     if logging_enabled():
#    2883         log_event(
#    2884             self,
#    2885             "reply_func_executed",
#    (...)
#    2889             reply=reply,
#    2890         )
#
# File /mnt/usb-Lexar/masterswork/git/FinRobot/finrobot_env/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:926, in ConversableAgent.register_nested_chats.<locals>.wrapped_reply_func(recipient, messages, sender, config)
#     925 def wrapped_reply_func(recipient, messages=None, sender=None, config=None):
# --> 926     return reply_func_from_nested_chats(chat_queue, recipient, messages, sender, config)
#
# File /mnt/usb-Lexar/masterswork/git/FinRobot/finrobot_env/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:822, in ConversableAgent._summary_from_nested_chats(chat_queue, recipient, messages, sender, config)
#     817 # Process carryover configuration
#     818 restore_chat_queue_message, original_chat_queue_message = ConversableAgent._process_chat_queue_carryover(
#     819     chat_queue, recipient, messages, sender, config
#     820 )
# --> 822 chat_to_run = ConversableAgent._get_chats_to_run(chat_queue, recipient, messages, sender, config)
#     823 if not chat_to_run:
#     824     return True, None
#
# File /mnt/usb-Lexar/masterswork/git/FinRobot/finrobot_env/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:644, in ConversableAgent._get_chats_to_run(chat_queue, recipient, messages, sender, config)
#     642     message = last_msg
#     643 if callable(message):
# --> 644     message = message(recipient, messages, sender, config)
#     645 # We only run chat that has a valid message. NOTE: This is prone to change depending on applications.
#     646 if message:
#
# Cell In[6], line 10, in order_message(recipient, messages, sender, config)
#       8 full_order = recipient.chat_messages_for_summary(sender)[-1]["content"]
#       9 txt_path = full_order.replace("instruction & resources saved to ", "").strip()
# ---> 10 with open(txt_path, "r") as f:
#      11     instruction = f.read() + "\n\nReply TERMINATE at the end of your response."
#      12 return instruction
#
# File /mnt/usb-Lexar/masterswork/git/FinRobot/finrobot_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../report/msft_income_statement_analysis.txt\n\n../report/msft_segment_analysis.txt'

# %% [markdown]
# The Rest Cells are optional, simply used to show the generated PDF

# %%
# !pip install PyMuPDF
# Out:
# Collecting PyMuPDF
#   Downloading PyMuPDF-1.24.9-cp310-none-manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting PyMuPDFb==1.24.9 (from PyMuPDF)
#   Downloading PyMuPDFb-1.24.9-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.4 kB)
# Downloading PyMuPDF-1.24.9-cp310-none-manylinux2014_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 91.7 MB/s eta 0:00:00
# Downloading PyMuPDFb-1.24.9-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (15.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 107.5 MB/s eta 0:00:00
# Installing collected packages: PyMuPDFb, PyMuPDF
# Successfully installed PyMuPDF-1.24.9 PyMuPDFb-1.24.9

# %%
import io
import fitz
from PIL import Image


pdf = fitz.open("/content/FinRobot/report/NextEra_Annual_Report_2024.pdf")
page = pdf.load_page(0)
pix = page.get_pixmap()

# Convert the Pixmap to a PIL Image
img = Image.open(io.BytesIO(pix.tobytes("png")))
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=596x842>
